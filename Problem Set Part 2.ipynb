# %% [markdown]
# Question 1
# Consider the following Python module:
# a = 0
# def b():
#  global a
#  a = c(a)
# def c(a):
#  return a + 2
# After importing the module into the interpreter, you execute:
# >>> b()
# >>> b()
# >>> b()
# >>> a
# ?
# What value is displayed when the last expression (a) is evaluated? Explain your
# answer by indicating what happens in every executed statement.

# %% [markdown]
# Answer
# =>a=0 This line sets a global variable 'a' to the value 0.
#
# =>def b(): and 'global a : This code segment defines a function named 'b' and specifies that it should access the global variable 'a'
#
# =>'a= c(a)" Inside the function 'b' ,It calls another function called 'c' using the current value of 'a' (Initially it is 0). The result of 'c(a)' is adding 2 to 'a', so 'a' gets updated to 2.
#
# =>def c(a):: This part defines a function named 'c' that takes an argument 'a'.
#
# =>return a + 2: Within the 'c' function, it returns the value of 'a' increased by 2.
#
# Executing The Above Statements
#
# b(): Call's the 'b' function. Inside 'b,' it updates the global variable 'a' to 2 by calling 'c(a)' (where 'c(0)' results in 0 + 2).
#
# b(): Calls 'b' again. Within 'b,' it takes the current value of 'a' (now 2) and calls 'c(a).' Consequently, 'c(2)' returns 2 + 2, which updates 'a' to 4.
#
# b(): Calling  'b' once more. Inside 'b,' it retrieves the current value of 'a' (which is now 4) and calls 'c(a).' Consequently, 'c(4)' results in 4 + 2. This updates 'a' to 6.

# %% [markdown]
# Question 2
# Function fileLength(), given to you, takes the name of a file as input and returns
# the length of the file:
# >>> fileLength('midterm.py')
# 284
# >>> fileLength('idterm.py')
# Traceback (most recent call last):
# File "<pyshell#34>", line 1, in <module>
#  fileLength('idterm.py')
# File "/Users/me/midterm.py", line 3, in fileLength
#  infile = open(filename)
# FileNotFoundError: [Errno 2] No such file or directory:
# 'idterm.py'
# As shown above, if the file cannot be found by the interpreter or if it cannot be read
# as a text file, an exception will be raised. Modify function fileLength() so that a
# friendly message is printed instead:
# >>> fileLength('midterm.py')
# 358
# >>> fileLength('idterm.py')
# File idterm.py not found.

# %%
def fileLength(filename):
    try:
        #open the file with the given filename to read it
        with open(filename, 'r') as infile:
            length = 0
            for line in infile: #read each line in the file and its length
                length += len(line)
            return length
    except FileNotFoundError:
        print(f"File {filename} not found.")

# Test the modified function
file_length = fileLength('midterm.py')
if file_length is not None:
    print(file_length)
file_length = fileLength('idterm.py')
# Out:
# File midterm.py not found.
# File idterm.py not found.

# %% [markdown]
# Question 3
# Write a class named Marsupial that can be used as shown below:
# >>> m = Marsupial()
# >>> m.put_in_pouch('doll')
# >>> m.put_in_pouch('firetruck')
# >>> m.put_in_pouch('kitten')
# >>> m.pouch_contents()
# ['doll', 'firetruck', 'kitten']
# Now write a class named Kangaroo as a subclass of Marsupial that inherits all the
# attributes of Marsupial and also:
# a. extends the Marsupial __init__ constructor to take, as input, the
# coordinates x and y of the Kangaroo object,
# b. supports method jump that takes number values dx and dy as input and
# moves the kangaroo by dx units along the x-axis and by dy units along the yaxis, and
# c. overloads the __str__ operator so it behaves as shown below.
# >>> k = Kangaroo(0,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (0,0)
# >>> k.put_in_pouch('doll')
# >>> k.put_in_pouch('firetruck')
# >>> k.put_in_pouch('kitten')
# >>> k.pouch_contents()
# ['doll', 'firetruck', 'kitten']
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (3,0)

# %%
class Marsupial:
    def __init__(self):
        self.pouch = [] #open an empty pouch list for the base class

    def put_in_pouch(self, item):
        self.pouch.append(item)

    def pouch_contents(self):
        return self.pouch

class Kangaroo(Marsupial):
    def __init__(self, x, y):
        super().__init__()
        self.x = x
        self.y = y

    def jump(self, dx, dy):
        self.x += dx
        self.y += dy

    def __str__(self):
        return f"I am a Kangaroo located at coordinates ({self.x},{self.y})"

# Executing the classes
m = Marsupial()
m.put_in_pouch('doll')
m.put_in_pouch('firetruck')
m.put_in_pouch('kitten')
print(m.pouch_contents())  # Output: ['doll', 'firetruck', 'kitten']

k = Kangaroo(0, 0)  # Provide initial coordinates (0, 0) when creating a Kangaroo instance
print(k)  # Output: I am a Kangaroo located at coordinates (0, 0)
k.put_in_pouch('joey')
k.put_in_pouch('stick')
print(k.pouch_contents())  # Output: ['joey', 'stick']

k.jump(1, 0)
k.jump(1, 0)
k.jump(1, 0)
print(k)  # Output: I am a Kangaroo located at coordinates (3, 0)
# Out:
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (0,0)
# ['joey', 'stick']
# I am a Kangaroo located at coordinates (3,0)

# %% [markdown]
# Question 4
# Write function collatz() that takes a positive integer x as input and prints the
# Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying
# this rule to the previous number x in the sequence:
# x = {
# 𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛
# 3𝑥 + 1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑
# Your function should stop when the sequence gets to number 1. Your
# implementation must be recursive, without any loops.
# >>> collatz(1)
# 1
# >>> collatz(10)
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %%
def collatz(x):
    # Base case: Stop when x reaches 1
    if x == 1:
        print(1)
    else:
        print(x)
        # Check if x is even
        if x % 2 == 0:
            collatz(x // 2)  # Apply the rule x = x/2 for even numbers
        else:
            collatz(3 * x + 1)  # Apply the rule x = 3x + 1 for odd numbers

# Evaluating the function with example inputs
collatz(1)
collatz(10)
# Out:
# 1
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# Question 5
# Write a recursive method binary() that takes a non-negative
# integer n and prints the binary representation of integer n.
# >>> binary(0)
# 0
# >>> binary(1)
# 1
# >>> binary(3)
# 11
# >>> binary(9)
# 1001

# %%
def binary(n):
    if n > 1:
        binary(n // 2)
    print(n % 2, end='')

# Evaluating cases
binary(0) 
print() #Print new line   
binary(1) 
print()
binary(3)  
print()
binary(9)
# Out:
# 0
# 1
# 11
# 1001

# %% [markdown]
# Question 8
# Write SQL queries on the below database table that return:
# a) All the temperature data.
# b) All the cities, but without repetition.
# c) All the records for India.
# d) All the Fall records.
# e) The city, country, and season for which the average rainfall is between 200
# and 400 millimeters.
# f) The city and country for which the average Fall temperature is above 20
# degrees, in increasing temperature order.
# g) The total annual rainfall for Cairo.
# h) The total rainfall for each season.

# %%
import sqlite3

conn = sqlite3.connect('Benil_Pailose.db')
cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE weather 
    (City TEXT, Country TEXT, Season TEXT, "Temperature(C)" FLOAT, "Rainfall(mm)" FLOAT)
''')

weather_data = [
    ('Mumbai', 'India', 'Winter', 24.8, 5.9),
    ('Mumbai', 'India', 'Spring', 28.4, 16.2),
    ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
    ('Mumbai', 'India', 'Fall', 27.6, 346.0),
    ('London', 'United Kingdom', 'Winter', 4.2, 207.7),
    ('London', 'United Kingdom', 'Spring', 8.3, 169.6),
    ('London', 'United Kingdom', 'Summer', 15.7, 157.0),
    ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
    ('Cairo', 'Egypt', 'Winter', 13.6, 16.5),
    ('Cairo', 'Egypt', 'Spring', 20.7, 6.5),
    ('Cairo', 'Egypt', 'Summer', 27.7, 0.1),
    ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)
]

cursor.executemany('''
    INSERT INTO weather (City, Country, Season, "Temperature(C)", "Rainfall(mm)")
    VALUES (?, ?, ?, ?, ?)
''', weather_data)

# a) All the temperature data.
cursor.execute('SELECT "Temperature(C)" FROM weather')
temperature_data = cursor.fetchall()

#b) All the cities, but without repetition.
cursor.execute('SELECT DISTINCT City FROM weather')
unique_cities = cursor.fetchall()

#c) All the records for India.
cursor.execute('SELECT * FROM weather WHERE Country = "India"')
india_records = cursor.fetchall()

#d) All the Fall records
cursor.execute('SELECT * FROM weather WHERE Season = "Fall"')
fall_records = cursor.fetchall()

#e) The city, country, and season for which the average rainfall is between 200 and 400 millimeters.
cursor.execute('''
    SELECT City, Country, Season
    FROM weather
    GROUP BY City, Country, Season
    HAVING AVG("Rainfall(mm)") BETWEEN 200 AND 400
''')
rainfall_between_200_400 = cursor.fetchall()

#f) The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order.
cursor.execute('''
    SELECT City, Country
    FROM weather
    WHERE Season = "Fall"
    GROUP BY City, Country
    HAVING AVG("Temperature(C)") > 20
    ORDER BY AVG("Temperature(C)") ASC
''')
high_temp_cities_in_fall = cursor.fetchall()

#g) The total annual rainfall for Cairo.
cursor.execute('SELECT SUM("Rainfall(mm)") AS "Total Rainfall" FROM weather WHERE City = "Cairo"')
cairo_total_rainfall = cursor.fetchone()[0]

#h) The total rainfall for each season.
cursor.execute('SELECT Season, SUM("Rainfall(mm)") AS "Total Rainfall" FROM weather GROUP BY Season')
total_rainfall_by_season = cursor.fetchall()

# Print the results
print("a) All Temperature Data:", temperature_data)
print("b) All Unique Cities:", unique_cities)
print("c) Records for India:", india_records)
print("d) Fall Records:", fall_records)
print("e) Average Rainfall between 200 and 400:", rainfall_between_200_400)
print("f) High-Temperature Cities in Fall:", high_temp_cities_in_fall)
print("g) Total Rainfall for Cairo:", cairo_total_rainfall)
print("h) Total Rainfall by Season:", total_rainfall_by_season)


conn.commit()
conn.close()
# Out:
# a) All Temperature Data: [(24.8,), (28.4,), (27.9,), (27.6,), (4.2,), (8.3,), (15.7,), (10.4,), (13.6,), (20.7,), (27.7,), (22.2,)]
# b) All Unique Cities: [('Mumbai',), ('London',), ('Cairo',)]
# c) Records for India: [('Mumbai', 'India', 'Winter', 24.8, 5.9), ('Mumbai', 'India', 'Spring', 28.4, 16.2), ('Mumbai', 'India', 'Summer', 27.9, 1549.4), ('Mumbai', 'India', 'Fall', 27.6, 346.0)]
# d) Fall Records: [('Mumbai', 'India', 'Fall', 27.6, 346.0), ('London', 'United Kingdom', 'Fall', 10.4, 218.5), ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)]
# e) Average Rainfall between 200 and 400: [('London', 'United Kingdom', 'Fall'), ('London', 'United Kingdom', 'Winter'), ('Mumbai', 'India', 'Fall')]
# f) High-Temperature Cities in Fall: [('Cairo', 'Egypt'), ('Mumbai', 'India')]
# g) Total Rainfall for Cairo: 27.6
# h) Total Rainfall by Season: [('Fall', 569.0), ('Spring', 192.29999999999998), ('Summer', 1706.5), ('Winter', 230.1)]

# %% [markdown]
# Question 9
# . Suppose list words is defined as follows:
# >>> words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over',
# 'the', 'lazy', 'dog']
# Write list comprehension expressions that use list words and generate the following
# lists:
# a) ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE',
# 'LAZY', 'DOG']
# b) ['the', 'quick', 'bown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog']
# c) [3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in list
# words).
# d) [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN',
# 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5],
# ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy',
# 4], ['DOG', 'dog', 3]] (the list containing a list for every word of list
# words, where each list contains the word in uppercase and lowercase and the
# length of the word.)
# e) ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog'] (the list of words in list words containing 4 or more
# characters.)

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over','the', 'lazy', 'dog']
# Create a new list containing the uppercase versions of each word
uppercase_words = [word.upper() for word in words]
print(uppercase_words)
# Create a new list containing the lowercase versions of each word
lowercase_words = [word.lower() for word in words]
print(lowercase_words)
# Create a new list containing the lengths of each word
word_lengths = [len(word) for word in words]
print(word_lengths)
# Create a new list that contains sublists for each word with its uppercase, lowercase, and length
word_info = [[word.upper(), word.lower(), len(word)] for word in words]
print(word_info)
# Create a new list containing words with 4 or more characters
long_words = [word for word in words if len(word) >= 4]
print(long_words)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
# ['quick', 'brown', 'jumps', 'over', 'lazy']
